# %%
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %% [markdown]
# # Convolution Auto Encoder

# %%
class ConvAutoEncoder(nn.Module):
    def __init__(self,multi_num=1):
        super(ConvAutoEncoder, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(
                in_channels=1,
                out_channels=multi_num*32,
                kernel_size=3,
                stride=1,
                padding=1),
            nn.BatchNorm2d(multi_num*32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,2)
        )

        self.conv2 = nn.Sequential(
            nn.Conv2d(
                in_channels=multi_num*32,
                out_channels=multi_num*16,
                kernel_size=3,
                stride=1,
                padding=1),
            nn.BatchNorm2d(multi_num*16),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,2)
        )

        self.conv3 = nn.Sequential(
            nn.Conv2d(
                in_channels=multi_num*16,
                out_channels=multi_num*8,
                kernel_size=3,
                stride=1,
                padding=1),
            nn.BatchNorm2d(multi_num*8),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,2)
        )

        self.conv4 = nn.Sequential(
            nn.Conv2d(
                in_channels=multi_num*8,
                out_channels=multi_num*4,
                kernel_size=3,
                stride=1,
                padding=1),
            nn.BatchNorm2d(multi_num*4),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,2)
        )

        self.trans_conv1 = nn.Sequential(
            nn.ConvTranspose2d(
                in_channels=multi_num*4,
                out_channels=multi_num*8,
                kernel_size=2,
                stride=2
            ),
            nn.BatchNorm2d(multi_num*8),
            nn.ReLU(inplace=True)
        )

        self.trans_conv2 = nn.Sequential(
            nn.ConvTranspose2d(
                in_channels=multi_num*8,
                out_channels=multi_num*16,
                kernel_size=2,
                stride=2
            ),
            nn.BatchNorm2d(multi_num*16),
            nn.ReLU(inplace=True)
        )

        self.trans_conv3 = nn.Sequential(
            nn.ConvTranspose2d(
                in_channels=multi_num*16,
                out_channels=multi_num*32,
                kernel_size=2,
                stride=2
            ),
            nn.BatchNorm2d(multi_num*32),
            nn.ReLU(inplace=True)
        )

        self.trans_conv4 = nn.Sequential(
            nn.ConvTranspose2d(
                in_channels=multi_num*32,
                out_channels=1,
                kernel_size=2,
                stride=2
            ),
            nn.BatchNorm2d(1),
            nn.Tanh()
        )

    def forward(self, x):
        out = list()
        out.append(self.conv1(x))
        out.append(self.conv2(out[0]))
        out.append(self.conv3(out[1]))
        out.append(self.conv4(out[2]))
        out.append(self.trans_conv1(out[3]))
        out.append(self.trans_conv2(out[4]))
        out.append(self.trans_conv3(out[5]))
        out.append(self.trans_conv4(out[6]))

        return out

# %% [markdown]
# # DataLoader

# %%
def make_datapath_list(mode="train"):

    image_list = list()
    if mode=="train":
        for index in range(1000):
            image_path = f"./data/train_images/image_0_{index}.jpg"
            image_list.append(image_path)
            image_path = f"./data/train_images/image_7_{index}.jpg"
            image_list.append(image_path)
            image_path = f"./data/train_images/image_8_{index}.jpg"
            image_list.append(image_path)
    if mode=="test":
        for index in range(100):
            image_path = f"./data/test_images/image_2_{index}.jpg"
            image_list.append(image_path)
            image_path = f"./data/test_images/image_3_{index}.jpg"
            image_list.append(image_path)
            image_path = f"./data/test_images/image_4_{index}.jpg"
            image_list.append(image_path)
            image_path = f"./data/test_images/image_0_{index}.jpg"
            image_list.append(image_path)
            image_path = f"./data/test_images/image_7_{index}.jpg"
            image_list.append(image_path)
            image_path = f"./data/test_images/image_8_{index}.jpg"
            image_list.append(image_path)

    return image_list

class ImageTransform():
    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, image):
        return self.data_transform(image)

class CAE_Image_Dataset(data.Dataset):

    def __init__(self, image_list, transform):
        self.image_list = image_list
        self.transform = transform

    def __len__(self):
        return len(self.image_list)

    def __getitem__(self, index):
        image_path = self.image_list[index]
        image = Image.open(image_path)

        image_transformed = self.transform(image)

        return image_transformed

# %%
# Check
train_image_list = make_datapath_list(mode="train")

mean = (0.5,)
std = (0.5,)
train_dataset = CAE_Image_Dataset(
    image_list=train_image_list,
    transform=ImageTransform(mean,std)
)

batch_size = 16

train_dataloader = data.DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True
)

batch_iterator = iter(train_dataloader)
images = next(batch_iterator)
print(images.size())
plt.imshow(images[0][0],'gray')
# Out:
# torch.Size([16, 1, 64, 64])

# %%
CAE_test = ConvAutoEncoder(multi_num=16)

input_x = images[0][0]
input_x = input_x.view(1,1,input_x.size(0),input_x.size(1))

output = CAE_test(input_x)

fig = plt.figure(figsize=(15,6))
for i in range(8):
    plt.subplot(2,8,i+1)
    image = output[i][0][0].detach().numpy()
    plt.imshow(image,'gray')
plt.tight_layout(pad=1.0)

# %% [markdown]
# # Training

# %%
def train_model(CAE, dataloader, epochs, model_name=None):
    # device
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print(f"Device:{device}")

    # loss function, optimizer
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(CAE.parameters(), lr=0.001)

    # outher settings
    CAE.to(device)
    CAE.train()
    batch_size = 16
    train_losses = list()
    torch.backends.cudnn.benchmark = True

    # training loop
    for epoch in range(epochs):
        epoch_start_time = time.time()
        epoch_loss = 0.0

        print(f"----------------")
        print(f"Epoch:{epoch}/{epochs-1}")

        # train per batch
        for images in dataloader:

            epoch_batch_size = images.size()[0]

            if epoch_batch_size == 1:
                continue

            images = images.to(device)

            optimizer.zero_grad()

            outputs = CAE(images)

            loss = criterion(outputs[7],images)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()*epoch_batch_size
        
        epoch_loss = epoch_loss/len(dataloader)
        print(f"Loss:{epoch_loss:.4f}")
        epoch_finish_time = time.time()
        print(f"Time:{epoch_finish_time-epoch_start_time:.4f} sec.")
        train_losses.append(epoch_loss)
        print(f"----------------")

        if model_name != None and epoch%25 == 0:
              file_name = f"{model_name}_{epoch}.pth"
              torch.save(CAE.state_dict(), f"model/gpu_{file_name}")
              torch.save(CAE.to('cpu').state_dict(), f"model/cpu_{file_name}")
              CAE.to(device)
    

    print("Finished!")

    return CAE, train_losses

# %%
epochs = 101

train_image_list = make_datapath_list()

mean = (0.5,)
std = (0.5,)
train_dataset = CAE_Image_Dataset(
    image_list=train_image_list,
    transform=ImageTransform(mean,std)
)

batch_size = 16

train_dataloader = data.DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True
)

CAE = ConvAutoEncoder(multi_num=4)

# %%
CAE_trained, train_losses = train_model(CAE,train_dataloader,epochs,model_name="CAE_4")
# Out:
# Device:cpu
# ----------------
# Epoch:0/100
# Loss:5.6682
# Time:47.2401 sec.
# ----------------
# ----------------
# Epoch:1/100
# Loss:2.6595
# Time:48.3294 sec.
# ----------------
# ----------------
# Epoch:2/100
# Loss:1.7171
# Time:49.4044 sec.
# ----------------
# ----------------
# Epoch:3/100
# Loss:1.2309
# Time:47.7071 sec.
# ----------------
# ----------------
# Epoch:4/100
# Loss:0.9335
# Time:49.1400 sec.
# ----------------
# ----------------
# Epoch:5/100
# Loss:0.7523
# Time:48.8820 sec.
# ----------------
# ----------------
# Epoch:6/100
# Loss:0.6164
# Time:47.4068 sec.
# ----------------
# ----------------
# Epoch:7/100
# Loss:0.5234
# Time:47.0057 sec.
# ----------------
# ----------------
# Epoch:8/100
# Loss:0.4630
# Time:47.1746 sec.
# ----------------
# ----------------
# Epoch:9/100
# Loss:0.4031
# Time:46.9375 sec.
# ----------------
# ----------------
# Epoch:10/100
# Loss:0.3652
# Time:46.1724 sec.
# ----------------
# ----------------
# Epoch:11/100
# Loss:0.3248
# Time:46.6967 sec.
# ----------------
# ----------------
# Epoch:12/100
# Loss:0.2953
# Time:46.5374 sec.
# ----------------
# ----------------
# Epoch:13/100
# Loss:0.2745
# Time:47.1711 sec.
# ----------------
# ----------------
# Epoch:14/100
# Loss:0.2522
# Time:46.2933 sec.
# ----------------
# ----------------
# Epoch:15/100
# Loss:0.2293
# Time:46.5092 sec.
# ----------------
# ----------------
# Epoch:16/100
# Loss:0.2141
# Time:47.7370 sec.
# ----------------
# ----------------
# Epoch:17/100
# Loss:0.1986
# Time:48.2515 sec.
# ----------------
# ----------------
# Epoch:18/100
# Loss:0.1946
# Time:47.3670 sec.
# ----------------
# ----------------
# Epoch:19/100
# Loss:0.1870
# Time:49.1948 sec.
# ----------------
# ----------------
# Epoch:20/100
# Loss:0.1778
# Time:49.0488 sec.
# ----------------
# ----------------
# Epoch:21/100
# Loss:0.1645
# Time:49.0602 sec.
# ----------------
# ----------------
# Epoch:22/100
# Loss:0.1597
# Time:45.5075 sec.
# ----------------
# ----------------
# Epoch:23/100
# Loss:0.1564
# Time:45.7192 sec.
# ----------------
# ----------------
# Epoch:24/100
# Loss:0.1492
# Time:45.1627 sec.
# ----------------
# ----------------
# Epoch:25/100
# Loss:0.1429
# Time:44.3987 sec.
# ----------------
# ----------------
# Epoch:26/100
# Loss:0.1391
# Time:45.5754 sec.
# ----------------
# ----------------
# Epoch:27/100
# Loss:0.1327
# Time:44.3180 sec.
# ----------------
# ----------------
# Epoch:28/100
# Loss:0.1356
# Time:44.1499 sec.
# ----------------
# ----------------
# Epoch:29/100
# Loss:0.1259
# Time:45.1300 sec.
# ----------------
# ----------------
# Epoch:30/100
# Loss:0.1224
# Time:44.7357 sec.
# ----------------
# ----------------
# Epoch:31/100
# Loss:0.1242
# Time:43.8541 sec.
# ----------------
# ----------------
# Epoch:32/100
# Loss:0.1205
# Time:44.6419 sec.
# ----------------
# ----------------
# Epoch:33/100
# Loss:0.1166
# Time:44.8303 sec.
# ----------------
# ----------------
# Epoch:34/100
# Loss:0.1128
# Time:44.1845 sec.
# ----------------
# ----------------
# Epoch:35/100
# Loss:0.1125
# Time:44.5789 sec.
# ----------------
# ----------------
# Epoch:36/100
# Loss:0.1099
# Time:45.5800 sec.
# ----------------
# ----------------
# Epoch:37/100
# Loss:0.1076
# Time:48.8805 sec.
# ----------------
# ----------------
# Epoch:38/100
# Loss:0.1059
# Time:47.6012 sec.
# ----------------
# ----------------
# Epoch:39/100
# Loss:0.1006
# Time:45.4741 sec.
# ----------------
# ----------------
# Epoch:40/100
# Loss:0.1018
# Time:45.9326 sec.
# ----------------
# ----------------
# Epoch:41/100
# Loss:0.0985
# Time:46.3082 sec.
# ----------------
# ----------------
# Epoch:42/100
# Loss:0.0967
# Time:46.6333 sec.
# ----------------
# ----------------
# Epoch:43/100
# Loss:0.0965
# Time:46.0803 sec.
# ----------------
# ----------------
# Epoch:44/100
# Loss:0.0958
# Time:45.6123 sec.
# ----------------
# ----------------
# Epoch:45/100
# Loss:0.0915
# Time:44.7611 sec.
# ----------------
# ----------------
# Epoch:46/100
# Loss:0.0951
# Time:45.4057 sec.
# ----------------
# ----------------
# Epoch:47/100
# Loss:0.0902
# Time:45.4263 sec.
# ----------------
# ----------------
# Epoch:48/100
# Loss:0.0885
# Time:44.5907 sec.
# ----------------
# ----------------
# Epoch:49/100
# Loss:0.0895
# Time:44.9917 sec.
# ----------------
# ----------------
# Epoch:50/100
# Loss:0.0887
# Time:44.7900 sec.
# ----------------
# ----------------
# Epoch:51/100
# Loss:0.0847
# Time:44.7828 sec.
# ----------------
# ----------------
# Epoch:52/100
# Loss:0.0854
# Time:46.3959 sec.
# ----------------
# ----------------
# Epoch:53/100
# Loss:0.0832
# Time:45.8731 sec.
# ----------------
# ----------------
# Epoch:54/100
# Loss:0.0805
# Time:46.8014 sec.
# ----------------
# ----------------
# Epoch:55/100
# Loss:0.0868
# Time:46.1812 sec.
# ----------------
# ----------------
# Epoch:56/100
# Loss:0.0819
# Time:46.7214 sec.
# ----------------
# ----------------
# Epoch:57/100
# Loss:0.0793
# Time:44.3874 sec.
# ----------------
# ----------------
# Epoch:58/100
# Loss:0.0822
# Time:42.8518 sec.
# ----------------
# ----------------
# Epoch:59/100
# Loss:0.0778
# Time:43.3782 sec.
# ----------------
# ----------------
# Epoch:60/100
# Loss:0.0821
# Time:43.2442 sec.
# ----------------
# ----------------
# Epoch:61/100
# Loss:0.0766
# Time:42.9349 sec.
# ----------------
# ----------------
# Epoch:62/100
# Loss:0.0762
# Time:42.7454 sec.
# ----------------
# ----------------
# Epoch:63/100
# Loss:0.0777
# Time:44.0935 sec.
# ----------------
# ----------------
# Epoch:64/100
# Loss:0.0752
# Time:43.4167 sec.
# ----------------
# ----------------
# Epoch:65/100
# Loss:0.0748
# Time:43.2808 sec.
# ----------------
# ----------------
# Epoch:66/100
# Loss:0.0775
# Time:43.2657 sec.
# ----------------
# ----------------
# Epoch:67/100
# Loss:0.0758
# Time:43.5783 sec.
# ----------------
# ----------------
# Epoch:68/100
# Loss:0.0742
# Time:43.7422 sec.
# ----------------
# ----------------
# Epoch:69/100
# Loss:0.0730
# Time:43.3875 sec.
# ----------------
# ----------------
# Epoch:70/100
# Loss:0.0716
# Time:43.9646 sec.
# ----------------
# ----------------
# Epoch:71/100
# Loss:0.0715
# Time:43.2063 sec.
# ----------------
# ----------------
# Epoch:72/100
# Loss:0.0725
# Time:43.1146 sec.
# ----------------
# ----------------
# Epoch:73/100
# Loss:0.0713
# Time:43.5375 sec.
# ----------------
# ----------------
# Epoch:74/100
# Loss:0.0709
# Time:44.1140 sec.
# ----------------
# ----------------
# Epoch:75/100
# Loss:0.0706
# Time:43.5756 sec.
# ----------------
# ----------------
# Epoch:76/100
# Loss:0.0729
# Time:43.6815 sec.
# ----------------
# ----------------
# Epoch:77/100
# Loss:0.0705
# Time:43.5237 sec.
# ----------------
# ----------------
# Epoch:78/100
# Loss:0.0695
# Time:44.2291 sec.
# ----------------
# ----------------
# Epoch:79/100
# Loss:0.0698
# Time:45.2597 sec.
# ----------------
# ----------------
# Epoch:80/100
# Loss:0.0685
# Time:42.9002 sec.
# ----------------
# ----------------
# Epoch:81/100
# Loss:0.0684
# Time:42.3233 sec.
# ----------------
# ----------------
# Epoch:82/100
# Loss:0.0674
# Time:45.0309 sec.
# ----------------
# ----------------
# Epoch:83/100
# Loss:0.0667
# Time:43.9697 sec.
# ----------------
# ----------------
# Epoch:84/100
# Loss:0.0673
# Time:42.4243 sec.
# ----------------
# ----------------
# Epoch:85/100
# Loss:0.0658
# Time:42.9609 sec.
# ----------------
# ----------------
# Epoch:86/100
# Loss:0.0664
# Time:42.8863 sec.
# ----------------
# ----------------
# Epoch:87/100
# Loss:0.0658
# Time:43.1259 sec.
# ----------------
# ----------------
# Epoch:88/100
# Loss:0.0646
# Time:42.6112 sec.
# ----------------
# ----------------
# Epoch:89/100
# Loss:0.0662
# Time:42.1999 sec.
# ----------------
# ----------------
# Epoch:90/100
# Loss:0.0665
# Time:43.0167 sec.
# ----------------
# ----------------
# Epoch:91/100
# Loss:0.0657
# Time:42.1775 sec.
# ----------------
# ----------------
# Epoch:92/100
# Loss:0.0657
# Time:42.2904 sec.
# ----------------
# ----------------
# Epoch:93/100
# Loss:0.0640
# Time:42.1485 sec.
# ----------------
# ----------------
# Epoch:94/100
# Loss:0.0645
# Time:42.0793 sec.
# ----------------
# ----------------
# Epoch:95/100
# Loss:0.0639
# Time:42.1349 sec.
# ----------------
# ----------------
# Epoch:96/100
# Loss:0.0641
# Time:42.9404 sec.
# ----------------
# ----------------
# Epoch:97/100
# Loss:0.0634
# Time:43.1389 sec.
# ----------------
# ----------------
# Epoch:98/100
# Loss:0.0643
# Time:43.1321 sec.
# ----------------
# ----------------
# Epoch:99/100
# Loss:0.0625
# Time:43.7944 sec.
# ----------------
# ----------------
# Epoch:100/100
# Loss:0.0640
# Time:44.2506 sec.
# ----------------
# Finished!

# %%
plt.plot(range(epochs),train_losses)

# %% [markdown]
# # Result

# %%
# test
test_image_list = make_datapath_list(mode="test")

mean = (0.5,)
std = (0.5,)
test_dataset = CAE_Image_Dataset(
    image_list=test_image_list,
    transform=ImageTransform(mean,std)
)

batch_size = 6

test_dataloader = data.DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=True
)

# %%
batch_iterator = iter(test_dataloader)
images = next(batch_iterator)

fig = plt.figure(figsize=(15,6))
for i in range(6):
    input_x = images[i][0]
    input_x = input_x.view(1,1,input_x.size(0),input_x.size(1))

    outputs = CAE_trained(input_x)

    plt.subplot(2,6,i+1)
    plt.imshow(images[i][0],'gray')

    plt.subplot(2,6,6+i+1)
    image = outputs[7][0][0].detach().numpy()
    plt.imshow(image,'gray')
plt.tight_layout(pad=1.0)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
batch_iterator = iter(test_dataloader)
images = next(batch_iterator)

input_x = images[2][0].to(device)
input_x = input_x.view(1,1,input_x.size(0),input_x.size(1))
fig = plt.figure(figsize=(15,6))
plt.subplot(2,5,1)
plt.imshow(input_x[0][0].to('cpu').detach().numpy(),'gray')

outputs = CAE_trained(input_x)
for i in range(8):
    plt.subplot(2,5,i+2)
    image = outputs[i][0][0].to('cpu').detach().numpy()
    plt.imshow(image,'gray')
plt.tight_layout(pad=1.0)
